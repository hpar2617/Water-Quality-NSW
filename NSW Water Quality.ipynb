# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import missingno as msno
import shapely as shp

# %%
water= pd.read_csv('nsw-dpie-estuary-water-quality-data-20072020.csv')
water
# Out:
#       OrganisationCode CMARegionCode MERRegionName ProgramCode  \
# 0                  OEH            NR         North         MER
# 1                  OEH            NR         North         MER
# 2                  OEH            NR         North         MER
# 3                  OEH            NR         North         MER
# 4                  OEH            NR         North         MER
# ...                ...           ...           ...         ...
# 11195              OEH            SR         South         MER
# 11196              OEH            SR         South         MER
# 11197              OEH            SR         South         MER
# 11198              OEH            SR         South         MER
# 11199              OEH            SR         South         MER
#
#                ProjectCode  EstuaryNo      Estuary EstuaryCode LGACode  \
# 0      MER-Est-Nth_2009-10        1.0  Tweed River         TWD     TSC
# ...

# %%
water.dtypes
# isnull.sum()
# dropnull/dropna
# z-score
# normalisation 
# time and date to datetime
# measurements starting with secchi- numerical- float 
# start/end long/lat numerical 
# https://towardsdatascience.com/6-python-container-data-types-you-should-know-81dad6c4f61d
# Coordinate = namedtuple('Coordinate', ['latitude', 'longitude'])
# c1._fields()
# GDA94 geographic SRID
# 
#
# Out:
# OrganisationCode         object
# CMARegionCode            object
# MERRegionName            object
# ProgramCode              object
# ProjectCode              object
# EstuaryNo               float64
# Estuary                  object
# EstuaryCode              object
# LGACode                  object
# MarineParkCode           object
# EstuaryTypeCode          object
# DisturbanceClassCode     object
# TripType                 object
# TripCode                 object
# TripNumber                int64
# Time                     object
# SiteTypeName             object
# SiteTypeCode             object
# Zone                     object
# SiteCode                 object
# Date                     object
# StartLatitude            object
# StartLongitude           object
# EndLatitude             float64
# EndLongitude            float64
# Entrance                 object
# Tide                     object
# Secchi_m                 object
# Depth_m                  object
# ...

# %%
msno.matrix(water,labels=True)
# Out:
# <AxesSubplot:>
